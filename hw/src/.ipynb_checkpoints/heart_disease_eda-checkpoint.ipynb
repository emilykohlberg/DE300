# %%
import pandas as pd
import csv

import matplotlib.pyplot as plt
import seaborn as sns

import xml.etree.ElementTree as ET
import psycopg2

#required for navigating machine's directory
import glob
import os.path

#required for communicating with SQL database
from sqlalchemy import create_engine

from utilities import insert_to_table

# %%
conn_string  = "postgresql://myuser:mypassword@postgres-container/mydatabase"
rawdata_path = "../rawdata/"
staging_data_dir = '../staging_data'

# %% [markdown]
# ## Read in the dataset and filter empty data

# %%
def insert_to_table(data: pd.DataFrame, table_name:str):
    db = create_engine(conn_string)
    conn = db.connect()
    data.to_sql(table_name, conn, if_exists="replace", index=False)
    conn.close()

# %%
def extract_from_csv(file_to_process: str) -> pd.DataFrame:
    with open(file_to_process, 'r') as file:
        reader = csv.reader(file)
        header = next(reader)

    data = pd.read_csv(file_to_process)
    data = data.dropna(axis=1, how='all')
    extracted_data = pd.DataFrame(columns = header)
    extracted_data = pd.concat([extracted_data, data], ignore_index=True)
    return extracted_data

# %%
def filter_df(df: pd.DataFrame) -> pd.DataFrame:

    # drop empty cols
    df = df.dropna(axis=1, how='all')

    # drop rows with only age and everything else null
    filtered_rows_index = df[~(df.drop(columns=['age']).isnull().all(axis=1) & ~df['age'].isnull())].index
    df = df.loc[filtered_rows_index]
    df['age'] = pd.to_numeric(df['age'], errors='coerce')


    # drop rows with all nan
    df = df[~df.isnull().all(axis=1)]

    return df

# %% [markdown]
# ## Extract

# %%
initial_df = extract_from_csv("../rawdata/heart_disease.csv")
df = filter_df(initial_df)
# Out:
# /tmp/ipykernel_661/3615485252.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   extracted_data = pd.concat([extracted_data, data], ignore_index=True)

# %%
# first 5 rows of data
df.head(5)
# Out:
#     age  sex  painloc  painexer  relrest   cp  trestbps  htn   chol  smoke  \
# 0  63.0  1.0      NaN       NaN      NaN  1.0     145.0  1.0  233.0    NaN
# 1  67.0  1.0      NaN       NaN      NaN  4.0     160.0  1.0  286.0    NaN
# 2  67.0  1.0      NaN       NaN      NaN  4.0     120.0  1.0  229.0    NaN
# 3  37.0  1.0      NaN       NaN      NaN  3.0     130.0  0.0  250.0    NaN
# 4  41.0  0.0      NaN       NaN      NaN  2.0     130.0  1.0  204.0    NaN
#
#    ...  exeref  exerwm  thal  thalsev  thalpul  earlobe  cmo  cday   cyr  \
# 0  ...     NaN     NaN   6.0      NaN      NaN      NaN  2.0  16.0  81.0
# 1  ...     NaN     NaN   3.0      NaN      NaN      NaN  2.0   5.0  81.0
# 2  ...     NaN     NaN   7.0      NaN      NaN      NaN  2.0  20.0  81.0
# 3  ...     NaN     NaN   3.0      NaN      NaN      NaN  2.0   4.0  81.0
# 4  ...     NaN     NaN   3.0      NaN      NaN      NaN  2.0  18.0  81.0
#
#    target
# 0     0.0
# 1     1.0
# 2     1.0
# 3     0.0
# 4     0.0
#
# [5 rows x 54 columns]

# %%
# renaming ekgday(day to ekgday for consistency
df = df.rename(columns={'ekgday(day': 'ekgday'})

# %%
insert_to_table(data = df, table_name = 'extracted_hd')

# %% [markdown]
# ## Transform

# %%
def transform(table_name):
    db = create_engine(conn_string)

    df = pd.read_sql_query(f'SELECT * FROM {table_name}',con=db)

    print(f"Shape of data {df.shape}")

    print(f"Shape of data {df.shape}")

    # write to parquet
    df.to_parquet(os.path.join(staging_data_dir, staging_file))

# %%
table_name = 'extracted_hd'
staging_file = 'head_disease.parquet'
transform(table_name)
# Out:
# Shape of data (899, 54)
# Shape of data (899, 54)

# %% [markdown]
# ## Load

# %%
def load(staging_data_dir) -> pd.DataFrame:
    data = pd.DataFrame()
    for parquet_file in glob.glob(os.path.join(staging_data_dir, "*.parquet")):
        data = pd.concat([pd.read_parquet(parquet_file),data])

    insert_to_table(data = data, table_name = 'ml_hd_data')

    return data

data = load(staging_data_dir)
print(data.shape)
# Out:
# (899, 54)

# %%
data
# Out:
#       age  sex  painloc  painexer  relrest   cp  trestbps  htn   chol  smoke  \
# 0    63.0  1.0      NaN       NaN      NaN  1.0     145.0  1.0  233.0    NaN
# 1    67.0  1.0      NaN       NaN      NaN  4.0     160.0  1.0  286.0    NaN
# 2    67.0  1.0      NaN       NaN      NaN  4.0     120.0  1.0  229.0    NaN
# 3    37.0  1.0      NaN       NaN      NaN  3.0     130.0  0.0  250.0    NaN
# 4    41.0  0.0      NaN       NaN      NaN  2.0     130.0  1.0  204.0    NaN
# ..    ...  ...      ...       ...      ...  ...       ...  ...    ...    ...
# 894  54.0  1.0      1.0       1.0      1.0  4.0     180.0  0.0    0.0    NaN
# 895  56.0  1.0      1.0       1.0      1.0  4.0     125.0  0.0    0.0    1.0
# 896  56.0  1.0      0.0       1.0      1.0  3.0     125.0  0.0    0.0    NaN
# 897  54.0  1.0      1.0       1.0      1.0  4.0     130.0  0.0    0.0    NaN
# 898  66.0  0.0      1.0       1.0      1.0  4.0     155.0  0.0    0.0    NaN
#
#      ...  exeref  exerwm  thal  thalsev  thalpul  earlobe  cmo  cday   cyr  \
# 0    ...     NaN     NaN   6.0      NaN      NaN      NaN  2.0  16.0  81.0
# 1    ...     NaN     NaN   3.0      NaN      NaN      NaN  2.0   5.0  81.0
# 2    ...     NaN     NaN   7.0      NaN      NaN      NaN  2.0  20.0  81.0
# 3    ...     NaN     NaN   3.0      NaN      NaN      NaN  2.0   4.0  81.0
# 4    ...     NaN     NaN   3.0      NaN      NaN      NaN  2.0  18.0  81.0
# ..   ...     ...     ...   ...      ...      ...      ...  ...   ...   ...
# 894  ...     NaN     NaN   7.0      1.0      0.0      NaN  5.0   7.0  85.0
# 895  ...     NaN     NaN   7.0      2.0      0.0      NaN  6.0  20.0  85.0
# 896  ...     NaN     NaN   7.0      1.0      0.0      NaN  6.0  25.0  85.0
# 897  ...     NaN     NaN   7.0      2.0      0.0      NaN  7.0   4.0  85.0
# 898  ...     NaN     NaN   7.0      1.0      0.0      NaN  7.0   4.0  85.0
#
#      target
# 0       0.0
# 1       1.0
# 2       1.0
# 3       0.0
# 4       0.0
# ..      ...
# 894     1.0
# 895     1.0
# 896     1.0
# 897     1.0
# 898     1.0
#
# [899 rows x 54 columns]

# %%
def load_one(file_name, staging_data_dir) -> pd.DataFrame:

    data = pd.read_parquet(os.path.join(staging_data_dir, file_name))
    table_name = 'ml_' + file_name.split('.')[0]

    insert_to_table(data = data, table_name = 'ml')

    return data

# %% [markdown]
# ## Check DB

# %%
query = """
    SELECT table_name
    FROM information_schema.tables
    WHERE table_schema = 'public';
    """

db = create_engine(conn_string)

pd.read_sql_query(query,con=db)
# Out:
#      table_name
# 0  extracted_hd
# 1    ml_hd_data

# %% [markdown]
# ## Compute and analyze the various statistical measures

# %%
# Define the columns as numerical or categorical based on information from the dataset documentation

column_types = {
    'age': 'numerical', 
    'sex': 'categorical', 
    'painloc': 'categorical', 
    'painexer': 'categorical', 
    'relrest': 'categorical', 
    'pncaden': 'numerical', 
    'cp': 'categorical', 
    'trestbps': 'numerical', 
    'htn': 'categorical', 
    'chol': 'numerical', 
    'smoke': 'categorical', 
    'cigs': 'numerical', 
    'years': 'numerical', 
    'fbs': 'categorical', 
    'dm': 'categorical', 
    'famhist': 'categorical', 
    'restecg': 'categorical', 
    'ekgmo': 'categorical', 
    'ekgday': 'categorical', 
    'ekgyr': 'categorical', 
    'dig': 'categorical', 
    'prop': 'categorical', 
    'nitr': 'categorical', 
    'pro': 'categorical', 
    'diuretic': 'categorical', 
    'proto': 'categorical', 
    'thaldur': 'numerical', 
    'thaltime': 'numerical', 
    'met': 'numerical', 
    'thalach': 'numerical', 
    'thalrest': 'numerical', 
    'tpeakbps': 'numerical', 
    'tpeakbpd': 'numerical', 
    'dummy': 'numerical', 
    'trestbpd': 'numerical', 
    'exang': 'categorical', 
    'xhypo': 'categorical', 
    'oldpeak': 'numerical', 
    'slope': 'categorical', 
    'rldv5': 'numerical', 
    'rldv5e': 'numerical', 
    'ca': 'numerical', 
    'exerckm': 'numerical', 
    'restef': 'numerical', 
    'restwm': 'categorical', 
    'exeref': 'numerical', 
    'exerwm': 'categorical', 
    'thal': 'categorical', 
    'thalsev': 'numerical', 
    'thalpul': 'numerical', 
    'earlobe': 'numerical', 
    'cmo': 'categorical', 
    'cday': 'categorical', 
    'cyr': 'categorical', 
    'target': 'categorical'
}

cat_cols = [key for key, value in column_types.items() if value == 'categorical']
num_cols = [key for key, value in column_types.items() if value == 'numerical']

# %%
# analyzing the features of the df
def get_info(df: pd.DataFrame):
    res = df.describe().transpose()
    print(res.shape)
    res['missing_percent'] = [(df.shape[0] - res.loc[ind, 'count'])/df.shape[0] for ind in res.index]
    res['unique_val'] = [len(df.loc[:,ind].value_counts()) for ind in res.index]
    res['var_type'] = res.index.map(column_types)
    
    return res

# %%
info = get_info(data)
info
# Out:
# (54, 8)
#           count        mean         std    min       25%     50%      75%  \
# age       899.0   53.480534    9.435894  28.00   47.0000   54.00   60.000
# sex       899.0    0.790879    0.406908   0.00    1.0000    1.00    1.000
# painloc   617.0    0.920583    0.270607   0.00    1.0000    1.00    1.000
# painexer  617.0    0.593193    0.491637   0.00    0.0000    1.00    1.000
# relrest   613.0    0.672104    0.469830   0.00    0.0000    1.00    1.000
# cp        899.0    3.253615    0.928499   1.00    3.0000    4.00    4.000
# trestbps  840.0  132.101190   19.151127   0.00  120.0000  130.00  140.000
# htn       865.0    0.476301    0.499727   0.00    0.0000    0.00    1.000
# chol      869.0  198.759494  111.834415   0.00  175.0000  224.00  269.000
# smoke     230.0    0.517391    0.500787   0.00    0.0000    1.00    1.000
# cigs      479.0   19.118998   18.296273   0.00    0.0000   20.00   30.000
# years     467.0   18.796574   16.359145   0.00    0.0000   20.00   30.000
# fbs       809.0    0.166873    0.373093   0.00    0.0000    0.00    0.000
# dm         95.0    0.957895    0.201895   0.00    1.0000    1.00    1.000
# famhist   477.0    0.563941    0.496415   0.00    0.0000    1.00    1.000
# restecg   897.0    0.603122    0.803669   0.00    0.0000    0.00    1.000
# ekgmo     846.0    5.973995    3.486479   1.00    3.0000    6.00    9.000
# ekgday    845.0   15.493491    8.761939   1.00    8.0000   16.00   23.000
# ekgyr     846.0   84.056738    1.640204  81.00   83.0000   84.00   85.000
# dig       831.0    0.034898    0.183631   0.00    0.0000    0.00    0.000
# prop      833.0    0.283313    0.870965   0.00    0.0000    0.00    1.000
# nitr      834.0    0.266187    0.442228   0.00    0.0000    0.00    1.000
# pro       836.0    0.172249    0.377823   0.00    0.0000    0.00    0.000
# diuretic  817.0    0.112607    0.316306   0.00    0.0000    0.00    0.000
# proto     787.0   37.081321   50.144559   1.00    1.0000    5.00   75.000
# thaldur   843.0    8.655872    3.746617   1.00    6.0000    8.10   10.500
# thaltime  446.0    5.690359    3.994673   0.00    3.0000    6.00    8.000
# met       794.0   16.483123   30.772801   2.00    5.0000    7.00   10.000
# thalach   844.0  137.298578   25.965959  60.00  120.0000  140.00  157.000
# thalrest  843.0   75.487544   14.727961  37.00   65.0000   74.00   84.000
# tpeakbps  836.0  171.641148   25.734488  84.00  155.0000  170.00  190.000
# tpeakbpd  836.0   87.293062   14.734586  11.00   80.0000   88.00  100.000
# dummy     840.0  132.101190   19.151127   0.00  120.0000  130.00  140.000
# trestbpd  840.0   83.523810   10.252563   0.00   80.0000   80.00   90.000
# exang     844.0    0.390995    0.488263   0.00    0.0000    0.00    1.000
# xhypo     841.0    0.026159    0.159704   0.00    0.0000    0.00    0.000
# oldpeak   837.0    0.870490    1.080548  -2.60    0.0000    0.50    1.500
# slope     591.0    1.766497    0.621339   0.00    1.0000    2.00    2.000
# rldv5     474.0   14.398734    5.702942   2.00   10.0000   14.00   18.000
# rldv5e    757.0   54.914135   60.309425   2.00   12.0000   19.00  102.000
# ca        291.0    0.697595    1.052728   0.00    0.0000    0.00    1.000
# exerckm     1.0    0.000000         NaN   0.00    0.0000    0.00    0.000
# restef     28.0    0.531071    0.146195   0.22    0.4075    0.57    0.625
# restwm     30.0    1.033333    1.066200   0.00    0.0000    1.00    2.000
# exeref      2.0    0.550000    0.070711   0.50    0.5250    0.55    0.575
# exerwm      5.0    0.200000    0.447214   0.00    0.0000    0.00    0.000
# thal      422.0    5.018957    1.949388   1.00    3.0000    6.00    7.000
# thalsev   130.0    1.284615    0.958314   0.00    0.0000    1.00    2.000
# thalpul    44.0    0.295455    0.461522   0.00    0.0000    0.00    1.000
# earlobe     1.0    0.000000         NaN   0.00    0.0000    0.00    0.000
# cmo       888.0    6.122748    3.474114   1.00    3.0000    6.00    9.000
# cday      890.0   15.988764    8.860872   1.00    8.0000   16.00   23.750
# cyr       890.0   83.839326    4.407533   1.00   83.0000   84.00   85.000
# target    899.0    0.550612    0.497709   0.00    0.0000    1.00    1.000
#
#             max  missing_percent  unique_val     var_type
# age        77.0         0.000000          50    numerical
# sex         1.0         0.000000           2  categorical
# painloc     1.0         0.313682           2  categorical
# painexer    1.0         0.313682           2  categorical
# relrest     1.0         0.318131           2  categorical
# cp          4.0         0.000000           4  categorical
# trestbps  200.0         0.065628          60    numerical
# htn         1.0         0.037820           2  categorical
# chol      603.0         0.033370         213    numerical
# smoke       1.0         0.744160           2  categorical
# cigs       99.0         0.467186          25    numerical
# years      60.0         0.480534          42    numerical
# fbs         1.0         0.100111           2  categorical
# dm          1.0         0.894327           2  categorical
# famhist     1.0         0.469410           2  categorical
# restecg     2.0         0.002225           3  categorical
# ekgmo      12.0         0.058954          12  categorical
# ekgday     31.0         0.060067          31  categorical
# ekgyr      87.0         0.058954           7  categorical
# dig         1.0         0.075640           2  categorical
# prop       22.0         0.073415           3  categorical
# nitr        1.0         0.072303           2  categorical
# pro         1.0         0.070078           2  categorical
# diuretic    1.0         0.091212           2  categorical
# proto     200.0         0.124583          14  categorical
# thaldur    24.0         0.062291          86    numerical
# thaltime   20.0         0.503893          64    numerical
# met       200.0         0.116796          34    numerical
# thalach   202.0         0.061179         119    numerical
# thalrest  139.0         0.062291          75    numerical
# tpeakbps  240.0         0.070078          74    numerical
# tpeakbpd  134.0         0.070078          51    numerical
# dummy     200.0         0.065628          60    numerical
# trestbpd  120.0         0.065628          34    numerical
# exang       1.0         0.061179           2  categorical
# xhypo       1.0         0.064516           2  categorical
# oldpeak     6.2         0.068966          52    numerical
# slope       3.0         0.342603           4  categorical
# rldv5      36.0         0.472747          31    numerical
# rldv5e    270.0         0.157953         141    numerical
# ca          9.0         0.676307           5    numerical
# exerckm     0.0         0.998888           1    numerical
# restef      0.8         0.968854          24    numerical
# restwm      3.0         0.966630           4  categorical
# exeref      0.6         0.997775           2    numerical
# exerwm      1.0         0.994438           2  categorical
# thal        7.0         0.530590           7  categorical
# thalsev     3.0         0.855395           4    numerical
# thalpul     1.0         0.951057           2    numerical
# earlobe     0.0         0.998888           1    numerical
# cmo        12.0         0.012236          12  categorical
# cday       31.0         0.010011          31  categorical
# cyr        87.0         0.010011          11  categorical
# target      1.0         0.000000           2  categorical

# %%
info = get_info(data)

fig,axs = plt.subplots(14,4,figsize=(14,60))

for i,ind in enumerate(info.index):

    if info.loc[ind, 'var_type'] == 'numerical':
        sns.boxplot(data,y=ind,ax=axs[i//4, i%4],width=0.5)
        

    else:
        sns.countplot(data=data,x=ind,color='#1f77b4',ax=axs[i//4, i%4])
    
    axs[i//4, i%4].set_title(ind)

fig.tight_layout()
# Out:
# (54, 8)

# %% [markdown]
# Some things that I notice from the summary table and visualization:
# 1. There are a lot of outliers
# 2. Many columns only have a few values
# 3. A lot of features are categorical with 0 and 1

# %% [markdown]
# ### Missing values

# %% [markdown]
# There seem to be a lot of missing values from the columns.

# %%
data_missing = (data.isnull().sum()/data.shape[0]).round(2)
data_missing[data_missing > 0]
# Out:
# painloc     0.31
# painexer    0.31
# relrest     0.32
# trestbps    0.07
# htn         0.04
# chol        0.03
# smoke       0.74
# cigs        0.47
# years       0.48
# fbs         0.10
# dm          0.89
# famhist     0.47
# ekgmo       0.06
# ekgday      0.06
# ekgyr       0.06
# dig         0.08
# prop        0.07
# nitr        0.07
# pro         0.07
# diuretic    0.09
# proto       0.12
# thaldur     0.06
# thaltime    0.50
# met         0.12
# thalach     0.06
# thalrest    0.06
# tpeakbps    0.07
# tpeakbpd    0.07
# dummy       0.07
# trestbpd    0.07
# exang       0.06
# xhypo       0.06
# oldpeak     0.07
# slope       0.34
# rldv5       0.47
# rldv5e      0.16
# ca          0.68
# exerckm     1.00
# restef      0.97
# restwm      0.97
# exeref      1.00
# exerwm      0.99
# thal        0.53
# thalsev     0.86
# thalpul     0.95
# earlobe     1.00
# cmo         0.01
# cday        0.01
# cyr         0.01
# dtype: float64

# %% [markdown]
# ## Analyze missing values and come up with a strategy to impute them. You might need different imputation methods for different features. Justify your choices.

# %%
missing_indices = {}
for column in data.columns:
    missing_indices[column] = data.index[data[column].isna()].tolist()

# for column, indices in missing_indices.items():
#     print(f"Missing indices for column '{column}': {indices}")

# Create a heatmap of missing indices
plt.figure(figsize=(14, 6))
sns.heatmap(data.isna(), cmap='binary', cbar=False)
plt.title('Missing Values Heatmap')
plt.xlabel('Columns')
plt.ylabel('Indices')
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# I am filling in the missing values for pncaden, which is the whole column. Based on the documentation, this is supposed to be a sum of ['painloc', 'painexer', 'relrest'].

# %%
# this column is supposed to be the sum of three pain values
data['pncaden'] = data[['painloc', 'painexer', 'relrest']].sum(axis=1)

# %% [markdown]
# The black bars show the missing values. There seem to be chunks of missing values for the most part.

# %% [markdown]
# One option would be to fill the categorical values to be the mean of the others. The mode would not be a good choice because it would heavily skew the data since there are a lot of missing values, so it would impact the average a lot.
# I think a more appropriate way to fill them would be to create a model that uses the other values in the table to predict them because this would still allow for categorical values (ie. 0 and 1 rather than fraction). This is too complex to do right now without further analysis of the data.
#
# The numerical values can be filled in with the mean or mode. I still think a model would be a better way to fill these in, but I need to do more analysis first.
#
# For now, I will leave the missing values as NaN as not to skew the data incorrectly throughout my EDA.

# %% [markdown]
# ### Unused, but this how I would fill the missing values

# %%
# One option would be to fill the categorical values to be the mean of the others
df_filled = data

avg_cat_values = df_filled[cat_cols].mean()

df_filled[cat_cols] = df_filled[cat_cols].fillna(avg_cat_values)

# this column is supposed to be the sum of three pain values
df_filled['pncaden'] = df_filled[['painloc', 'painexer', 'relrest']].sum(axis=1)

# %%
info_filled = get_info(df_filled)
info_filled

# %%
# filling the numerical values to be the mode of the others
print(num_cols)
mode_num_values = df_filled[num_cols].mode().iloc[0]
print(mode_num_values)

df_filled[num_cols] = df_filled[num_cols].fillna(mode_num_values)

# %%
info_filled = get_info(df_filled)
info_filled

# %% [markdown]
# ## For the numerical features, identify outliers and appropriately deal with them. Justify your choices

# %%
len(data[num_cols].count()[data[num_cols].count() > 5])
# Out:
# 22

# %%
fig,axs = plt.subplots(6,4,figsize=(18,30))
i = 0

for ind in num_cols:

    if data[ind].count() > 5:
        sns.boxplot(data,y=ind,ax=axs[i//4, i%4],width=0.5)
        axs[i//4, i%4].set_title(ind)
        i+=1

fig.tight_layout()

# %%
for i,ind in enumerate(num_cols):

    print(i + 1, ": " + ind + "\n")

    mean = data[ind].mean()
    std = data[ind].std()

    outliers = data[ind][(data[ind] < (mean - 2 * std)) | (data[ind] > (mean + 2 * std))]
    print(outliers)
    print('-----------')
# Out:
# 1 : age
#
# 102    34.0
# 134    29.0
# 165    77.0
# 230    34.0
# 238    74.0
# 262    76.0
# 310    74.0
# 318    77.0
# 362    75.0
# 378    75.0
# 403    74.0
# 407    76.0
# 419    74.0
# 422    75.0
# 455    74.0
# 470    74.0
# 517    32.0
# 538    31.0
# 549    32.0
# 558    32.0
# 589    34.0
# 597    33.0
# 601    34.0
# 608    34.0
# 653    29.0
# 686    31.0
# 691    28.0
# 698    30.0
# 702    29.0
# 706    33.0
# 750    34.0
# 754    32.0
# 777    32.0
# 796    34.0
# 798    74.0
# 858    73.0
# Name: age, dtype: float64
# -----------
# 2 : pncaden
#
# Series([], Name: pncaden, dtype: float64)
# -----------
# 3 : trestbps
#
# 14     172.0
# 83     180.0
# 128    200.0
# 176    174.0
# 188    178.0
# 193    192.0
# 206    180.0
# 218    178.0
# 236    180.0
# 294    180.0
# 320      0.0
# 347    178.0
# 416    172.0
# 451    180.0
# 458    190.0
# 591    190.0
# 605    180.0
# 672    180.0
# 673    180.0
# 710     92.0
# 724    200.0
# 757    180.0
# 758    180.0
# 761    180.0
# 797     80.0
# 848    200.0
# 855    185.0
# 882    200.0
# 894    180.0
# Name: trestbps, dtype: float64
# -----------
# 4 : chol
#
# 155    564.0
# 367    458.0
# 510    468.0
# 512    518.0
# 558    529.0
# 585    466.0
# 632    603.0
# 733    491.0
# Name: chol, dtype: float64
# -----------
# 5 : cigs
#
# 10     75.0
# 38     60.0
# 39     99.0
# 46     60.0
# 62     60.0
# 63     60.0
# 64     60.0
# 74     80.0
# 100    60.0
# 122    60.0
# 149    70.0
# 172    60.0
# 242    60.0
# 268    80.0
# 319    60.0
# 329    80.0
# 337    60.0
# 342    60.0
# 343    60.0
# 346    65.0
# 364    60.0
# 402    60.0
# 433    60.0
# 654    60.0
# Name: cigs, dtype: float64
# -----------
# 6 : years
#
# 79     54.0
# 339    54.0
# 419    60.0
# Name: years, dtype: float64
# -----------
# 7 : thaldur
#
# 482    18.0
# 487    19.0
# 489    19.0
# 498    18.0
# 506    19.0
# 507    21.0
# 517    16.5
# 529    20.0
# 540    20.0
# 558    18.0
# 561    17.0
# 583    19.0
# 585    17.0
# 589    18.0
# 598    17.0
# 601    24.0
# 612    19.0
# 620    18.0
# 626    19.0
# 628    19.0
# 632    18.0
# 635    19.0
# 642    18.0
# 654    17.0
# 664    19.0
# 676    18.0
# 685    19.0
# 688    18.0
# 689    19.0
# 691    20.0
# 692    18.0
# 702    20.0
# 707    18.0
# 709    18.0
# 711    20.0
# 718    20.0
# 738     1.0
# 740    17.0
# 750    18.0
# 767    18.0
# 770    19.0
# 772    18.0
# Name: thaldur, dtype: float64
# -----------
# 8 : thaltime
#
# 52     15.0
# 540    19.0
# 545    15.0
# 585    15.0
# 632    17.5
# 718    19.0
# 747    14.5
# 748    20.0
# 780    14.0
# 783    17.8
# 792    14.3
# 796    15.8
# 820    14.0
# Name: thaltime, dtype: float64
# -----------
# 9 : met
#
# 776    100.0
# 827    100.0
# 828    150.0
# 829    100.0
# 830    150.0
# 832    100.0
# 833    100.0
# 834    150.0
# 835    150.0
# 837    150.0
# 839    100.0
# 840    125.0
# 841    100.0
# 842    150.0
# 844    100.0
# 845    100.0
# 846    150.0
# 847    150.0
# 849    100.0
# 850    100.0
# 851    100.0
# 853    100.0
# 855    100.0
# 856    100.0
# 857    100.0
# 859    150.0
# 860    100.0
# 861    100.0
# 862    200.0
# 863    100.0
# 864    150.0
# 865    150.0
# 866    100.0
# 867    150.0
# 868    150.0
# 869    100.0
# 870    100.0
# 871    100.0
# 872    100.0
# 873    100.0
# 875    125.0
# 876    100.0
# 877    150.0
# 878    150.0
# 880    150.0
# 881    150.0
# 884    150.0
# 886    150.0
# 887    150.0
# 892    100.0
# 893    100.0
# 894    100.0
# 895    100.0
# 896    100.0
# 897    150.0
# Name: met, dtype: float64
# -----------
# 10 : thalach
#
# 113    190.0
# 134    202.0
# 191    194.0
# 193    195.0
# 230    192.0
# 250     71.0
# 303     84.0
# 328     80.0
# 333     84.0
# 367     69.0
# 379     80.0
# 416     73.0
# 448     84.0
# 550     82.0
# 608    190.0
# 801     77.0
# 811     82.0
# 814     82.0
# 843     72.0
# 853     63.0
# 871     83.0
# 873     60.0
# 882     70.0
# 885     67.0
# 890     72.0
# 893     78.0
# Name: thalach, dtype: float64
# -----------
# 11 : thalrest
#
# 48     110.0
# 72      43.0
# 98     109.0
# 139     40.0
# 153    112.0
# 190    119.0
# 260    115.0
# 357    139.0
# 448     37.0
# 530    134.0
# 542    116.0
# 543    105.0
# 549    120.0
# 579    120.0
# 583     46.0
# 594    105.0
# 600    110.0
# 602    110.0
# 608    125.0
# 618    120.0
# 652    112.0
# 660    124.0
# 694    115.0
# 696    108.0
# 698    125.0
# 701    105.0
# 738    110.0
# 757    110.0
# 767    125.0
# 853     46.0
# 884    110.0
# 885     39.0
# 890     44.0
# Name: thalrest, dtype: float64
# -----------
# 12 : tpeakbps
#
# 8      120.0
# 55      90.0
# 144    230.0
# 167    112.0
# 173     84.0
# 201    224.0
# 227    116.0
# 228     98.0
# 237    120.0
# 240     98.0
# 250     92.0
# 280    232.0
# 318    110.0
# 331    120.0
# 336    120.0
# 337    100.0
# 370    110.0
# 385    110.0
# 512    230.0
# 517    230.0
# 524    230.0
# 543    240.0
# 551    230.0
# 565    230.0
# 568    230.0
# 570    230.0
# 578    240.0
# 587    230.0
# 606    240.0
# 611    228.0
# 612    235.0
# 658    230.0
# 678    240.0
# 686    120.0
# 736    240.0
# 746    230.0
# 757    120.0
# 767    230.0
# 783    230.0
# 803    230.0
# 826    120.0
# 885    120.0
# 890    110.0
# 891    115.0
# 893    120.0
# Name: tpeakbps, dtype: float64
# -----------
# 13 : tpeakbpd
#
# 9      120.0
# 11     118.0
# 55      50.0
# 102     40.0
# 150     45.0
# 156    118.0
# 180     56.0
# 190     50.0
# 224     26.0
# 250     56.0
# 261     40.0
# 280    120.0
# 294    120.0
# 413     11.0
# 524    120.0
# 552    130.0
# 557    130.0
# 568    120.0
# 570    120.0
# 575    120.0
# 612    120.0
# 613    120.0
# 646    118.0
# 654    118.0
# 669    120.0
# 674    134.0
# 715    120.0
# 725    120.0
# 736    120.0
# 746    120.0
# 759    120.0
# 815     55.0
# Name: tpeakbpd, dtype: float64
# -----------
# 14 : dummy
#
# 14     172.0
# 83     180.0
# 128    200.0
# 176    174.0
# 188    178.0
# 193    192.0
# 206    180.0
# 218    178.0
# 236    180.0
# 294    180.0
# 320      0.0
# 347    178.0
# 416    172.0
# 451    180.0
# 458    190.0
# 591    190.0
# 605    180.0
# 672    180.0
# 673    180.0
# 710     92.0
# 724    200.0
# 757    180.0
# 758    180.0
# 761    180.0
# 797     80.0
# 848    200.0
# 855    185.0
# 882    200.0
# 894    180.0
# Name: dummy, dtype: float64
# -----------
# 15 : trestbpd
#
# 8      105.0
# 39     110.0
# 143    105.0
# 180     60.0
# 235    106.0
# 236    110.0
# 261     50.0
# 297     60.0
# 318     60.0
# 320      0.0
# 337     60.0
# 373     60.0
# 407     58.0
# 502     60.0
# 623     50.0
# 625    106.0
# 725    110.0
# 748    110.0
# 761    105.0
# 773     60.0
# 787     60.0
# 792     60.0
# 797     60.0
# 838     60.0
# 848    120.0
# 859    110.0
# 871    105.0
# 879     60.0
# 881    105.0
# 882    110.0
# 892    110.0
# Name: trestbpd, dtype: float64
# -----------
# 16 : oldpeak
#
# 3      3.5
# 6      3.6
# 9      3.1
# 23     3.2
# 68     3.4
# 69     3.6
# 92     6.2
# 109    3.6
# 123    4.0
# 125    5.6
# 128    4.0
# 188    4.2
# 196    4.2
# 216    3.8
# 236    3.4
# 240    3.2
# 269    3.6
# 372    4.0
# 393    4.0
# 403    4.0
# 407    3.5
# 425    4.0
# 550    4.0
# 649    5.0
# 807   -2.6
# 808   -1.5
# 820    3.7
# 896   -2.0
# Name: oldpeak, dtype: float64
# -----------
# 17 : rldv5
#
# 336    27.0
# 340    29.0
# 362    26.0
# 372    28.0
# 378    36.0
# 387    31.0
# 420    30.0
# 421     2.0
# 444    27.0
# 452    26.0
# 482    26.0
# 505    27.0
# 532    31.0
# 558    28.0
# 582    27.0
# 620    28.0
# 783    26.0
# Name: rldv5, dtype: float64
# -----------
# 18 : rldv5e
#
# 1      185.0
# 10     200.0
# 14     231.0
# 16     197.0
# 20     200.0
# 25     220.0
# 26     270.0
# 32     220.0
# 33     176.0
# 43     195.0
# 59     210.0
# 69     176.0
# 79     225.0
# 80     204.0
# 94     200.0
# 96     180.0
# 98     190.0
# 123    180.0
# 125    176.0
# 128    210.0
# 138    227.0
# 152    220.0
# 157    176.0
# 161    190.0
# 178    178.0
# 181    230.0
# 182    206.0
# 188    222.0
# 202    179.0
# 207    180.0
# 213    190.0
# 228    177.0
# 236    252.0
# 237    230.0
# 238    253.0
# 256    190.0
# 258    195.0
# 269    240.0
# 270    200.0
# 277    185.0
# Name: rldv5e, dtype: float64
# -----------
# 19 : ca
#
# 1      3.0
# 40     3.0
# 62     3.0
# 92     3.0
# 93     3.0
# 105    3.0
# 120    3.0
# 123    3.0
# 149    3.0
# 158    3.0
# 165    3.0
# 180    3.0
# 184    3.0
# 192    3.0
# 194    3.0
# 196    3.0
# 198    3.0
# 210    3.0
# 237    3.0
# 521    9.0
# Name: ca, dtype: float64
# -----------
# 20 : exerckm
#
# Series([], Name: exerckm, dtype: float64)
# -----------
# 21 : restef
#
# 357    0.22
# Name: restef, dtype: float64
# -----------
# 22 : exeref
#
# Series([], Name: exeref, dtype: float64)
# -----------
# 23 : thalsev
#
# Series([], Name: thalsev, dtype: float64)
# -----------
# 24 : thalpul
#
# Series([], Name: thalpul, dtype: float64)
# -----------
# 25 : earlobe
#
# Series([], Name: earlobe, dtype: float64)
# -----------

# %% [markdown]
# Outliers:
# 1. age : N/A
# 2. pncaden : N/A (all NaN)
# 3. trestbps : high values might be an indicator of heart disease
#                0 I will CHANGE to NaN because 0 is impossible
# 4. chol : high values might be an indicator of heart disease
# 5. cigs : high values might be an indicator of heart disease
# 6. years : high values might be an indicator of heart disease
# 7. thaldur : high values might be an indicator of GOOD HEART, low values might be an indicator of heart disease
# 8. thaltime: outliers might be bad
# 9.met: mets achieved... not sure, but keep note of outliers
# 10. thalach : maximum heart rate achieved, outliers on both sides could be abnormal
# 11. thalrest : resting heart rate, outliers on both sides could be abnormal
# 12. tpeakbps : peak blood pressure 1, note outliers
# 13. tpeakbpd : peak blood pressure 1, note outliers
# 14. dummy : ignore, will delete this col
# 15. trestbpd : resting blood pressure, note outliers
# 16. oldpeak : ST depression induced by exercise relative to rest, note
# 17. rldv5 : height at rest, note
# 18.  rldv5 e: height at peak exercis, note
# 19. ca : number of major vessels (0-3) colored by flourosopy, note the outliers, change 9 to NaN
# 20. restckm : N/A
# 21. exerckm : N/A
# 22. restef : 1 outlier, doesn't seem that important
# 23. exeref : N/A
# 24. thalsev : N/A
# 25. thalpul : N/A
# 26. earlobe : N/A

# %%
for i,ind in enumerate(num_cols):

    print(ind + "\n")

    mean = data[ind].mean()
    std = data[ind].std()

    outliers_3 = data[ind][(data[ind] < (mean - 3 * std)) | (data[ind] > (mean + 3 * std))]
    print(outliers_3)
    print('-----------')
# Out:
# age
#
# Series([], Name: age, dtype: float64)
# -----------
# pncaden
#
# Series([], Name: pncaden, dtype: float64)
# -----------
# trestbps
#
# 128    200.0
# 193    192.0
# 320      0.0
# 458    190.0
# 591    190.0
# 724    200.0
# 848    200.0
# 882    200.0
# Name: trestbps, dtype: float64
# -----------
# chol
#
# 155    564.0
# 632    603.0
# Name: chol, dtype: float64
# -----------
# cigs
#
# 10     75.0
# 39     99.0
# 74     80.0
# 268    80.0
# 329    80.0
# Name: cigs, dtype: float64
# -----------
# years
#
# Series([], Name: years, dtype: float64)
# -----------
# thaldur
#
# 507    21.0
# 529    20.0
# 540    20.0
# 601    24.0
# 691    20.0
# 702    20.0
# 711    20.0
# 718    20.0
# Name: thaldur, dtype: float64
# -----------
# thaltime
#
# 540    19.0
# 718    19.0
# 748    20.0
# 783    17.8
# Name: thaltime, dtype: float64
# -----------
# met
#
# 828    150.0
# 830    150.0
# 834    150.0
# 835    150.0
# 837    150.0
# 840    125.0
# 842    150.0
# 846    150.0
# 847    150.0
# 859    150.0
# 862    200.0
# 864    150.0
# 865    150.0
# 867    150.0
# 868    150.0
# 875    125.0
# 877    150.0
# 878    150.0
# 880    150.0
# 881    150.0
# 884    150.0
# 886    150.0
# 887    150.0
# 897    150.0
# Name: met, dtype: float64
# -----------
# thalach
#
# Series([], Name: thalach, dtype: float64)
# -----------
# thalrest
#
# 357    139.0
# 530    134.0
# 549    120.0
# 579    120.0
# 608    125.0
# 618    120.0
# 660    124.0
# 698    125.0
# 767    125.0
# Name: thalrest, dtype: float64
# -----------
# tpeakbps
#
# 55     90.0
# 173    84.0
# 250    92.0
# Name: tpeakbps, dtype: float64
# -----------
# tpeakbpd
#
# 102     40.0
# 224     26.0
# 261     40.0
# 413     11.0
# 674    134.0
# Name: tpeakbpd, dtype: float64
# -----------
# dummy
#
# 128    200.0
# 193    192.0
# 320      0.0
# 458    190.0
# 591    190.0
# 724    200.0
# 848    200.0
# 882    200.0
# Name: dummy, dtype: float64
# -----------
# trestbpd
#
# 261     50.0
# 320      0.0
# 623     50.0
# 848    120.0
# Name: trestbpd, dtype: float64
# -----------
# oldpeak
#
# 92     6.2
# 125    5.6
# 188    4.2
# 196    4.2
# 649    5.0
# 807   -2.6
# Name: oldpeak, dtype: float64
# -----------
# rldv5
#
# 378    36.0
# Name: rldv5, dtype: float64
# -----------
# rldv5e
#
# 26     270.0
# 236    252.0
# 238    253.0
# 269    240.0
# Name: rldv5e, dtype: float64
# -----------
# ca
#
# 521    9.0
# Name: ca, dtype: float64
# -----------
# exerckm
#
# Series([], Name: exerckm, dtype: float64)
# -----------
# restef
#
# Series([], Name: restef, dtype: float64)
# -----------
# exeref
#
# Series([], Name: exeref, dtype: float64)
# -----------
# thalsev
#
# Series([], Name: thalsev, dtype: float64)
# -----------
# thalpul
#
# Series([], Name: thalpul, dtype: float64)
# -----------
# earlobe
#
# Series([], Name: earlobe, dtype: float64)
# -----------

# %% [markdown]
# With 3 stds, more specific

# %%
data = data.drop(columns=['dummy'])

# %%
column_types.pop('dummy')
# Out:
# 'numerical'

# %%
num_cols.remove('dummy')

# %%
data.loc[data['trestbps'] == 0, 'trestbps'] = float('nan')
data.loc[data['ca'] == 9, 'ca'] = float('nan')

# %% [markdown]
# I changed the outliers that seemed like incorrect information, but the others will be important for determining who is susceptible to heart disease in the future.

# %% [markdown]
# ## Feature transformations

# %%
cat_cols
# Out:
# ['sex',
#  'painloc',
#  'painexer',
#  'relrest',
#  'cp',
#  'htn',
#  'smoke',
#  'fbs',
#  'dm',
#  'famhist',
#  'restecg',
#  'ekgmo',
#  'ekgday',
#  'ekgyr',
#  'dig',
#  'prop',
#  'nitr',
#  'pro',
#  'diuretic',
#  'proto',
#  'exang',
#  'xhypo',
#  'slope',
#  'restwm',
#  'exerwm',
#  'thal',
#  'cmo',
#  'cday',
#  'cyr',
#  'target']

# %% [markdown]
# Decording the numeric categories for all the categorical features to make the graphs easier to understand.

# %%
data_feature_trans = data

# Define mappings for each column
mappings = {
    'sex': {0:'female',1:'male'},
    'painloc': {0:'otherwise',1:'substernal'},
    'painexer': {0:'otherwise',1:'provoked by exertion'},
    'relrest': {0:'otherwise',1:'relieved after rest'},
    'cp': {1:'typical angina',2:'atypical angina',3:'non-anginal pain',4:'asymptomatic'},
    'smoke': {0:'no',1:'yes'},
    'fbs': {0:'fbs less than or equal to 120',1:'fbs greater than 120'},
    'dm': {0:'no history of diabetes',1:'history of diabetes'},
    'famhist': {0:'no',1:'yes'},
    'restecg': {0:'normal',1:'having ST-T wave abnormality',2:'showing probable or definite left ventricular hypertrophy'},
    'ekgmo': {1: 'January', 2: 'February', 3: 'March', 4: 'April', 5: 'May', 6: 'June',
              7: 'July', 8: 'August', 9: 'September', 10: 'October', 11: 'November', 12: 'December'},
    'dig': {0:'no',1:'yes'},
    'prop': {0:'no',1:'yes'},
    'nitr': {0:'no',1:'yes'},
    'pro': {0:'no',1:'yes'},
    'diuretic': {0:'no',1:'yes'},
    'proto': {1: 'Bruce', 2: 'Kottus', 3: 'McHenry', 4: 'fast Balke', 5: 'Balke', 6: 'Noughton',
              7: 'bike 150 kpa min/min', 8: 'bike 125 kpa min/min', 9: 'bike 100 kpa min/min',
              10: 'bike 75 kpa min/min', 11: 'bike 50 kpa min/min', 12: 'arm ergometer', 0: 'no', 1: 'yes'},
    'exang': {0:'no',1:'yes'},
    'xhypo': {0:'no',1:'yes'},
    'slope': {1:'upsloping',2:'flat',3:'downsloping'},
    'restwm': {0:'none',1:'mild or moderate',2:'moderate or severe',3:'akinesis or dyskmem'},
    'exerwm': {0:'none',1:'mild or moderate',2:'moderate or severe',3:'akinesis or dyskmem'},
    'thal': {3:'normal',6:'fixed defect',7:'reversable defect'},
    'cmo': {1: 'January', 2: 'February', 3: 'March', 4: 'April', 5: 'May', 6: 'June',
            7: 'July', 8: 'August', 9: 'September', 10: 'October', 11: 'November', 12: 'December'}}

# Replace values that are not in the mapping with NaN
data_feature_trans.replace({col: {val: float('nan') for val in data_feature_trans[col].unique() if val not in mappings[col]} for col in mappings}, inplace=True)

# %%
data_feature_trans['sex'] = (
    data_feature_trans['sex']
    .replace(mappings['sex'])
    .astype('category'))

data_feature_trans['painloc'] = (
    data_feature_trans['painloc']
    .replace(mappings['painloc'])
    .astype('category'))

data_feature_trans['painexer'] = (
    data_feature_trans['painexer']
    .replace(mappings['painexer'])
    .astype('category'))

data_feature_trans['relrest'] = (
    data_feature_trans['relrest']
    .replace(mappings['relrest'])
    .astype('category'))

data_feature_trans['cp'] = (
    data_feature_trans['cp']
    .replace(mappings['cp'])
    .astype('category'))

data_feature_trans['smoke'] = (
    data_feature_trans['smoke']
    .replace(mappings['smoke'])
    .astype('category'))

data_feature_trans['fbs'] = (
    data_feature_trans['fbs']
    .replace(mappings['fbs'])
    .astype('category'))

data_feature_trans['dm'] = (
    data_feature_trans['dm']
    .replace(mappings['dm'])
    .astype('category'))

data_feature_trans['famhist'] = (
    data_feature_trans['famhist']
    .replace(mappings['famhist'])
    .astype('category'))
data_feature_trans = data_feature_trans.rename(columns={'famhist': 'family_history_of_coronary_artery_disease'})
column_types['family_history_of_coronary_artery_disease'] = column_types.pop('famhist')


data_feature_trans['restecg'] = (
    data_feature_trans['restecg']
    .replace(mappings['restecg'])
    .astype('category'))

data_feature_trans['ekgmo'] = (
    data_feature_trans['ekgmo']
    .replace(mappings['ekgmo'])
    .astype('category'))

data_feature_trans['dig'] = (
    data_feature_trans['dig']
    .replace(mappings['dig'])
    .astype('category'))
data_feature_trans = data_feature_trans.rename(columns={'dig': 'digitalis_used_during_exercise'})
column_types['digitalis_used_during_exercise'] = column_types.pop('dig')

data_feature_trans['prop'] = (
    data_feature_trans['prop']
    .replace(mappings['prop'])
    .astype('category'))
data_feature_trans = data_feature_trans.rename(columns={'prop': 'Beta_blocker_used_during_exercise'})
column_types['Beta_blocker_used_during_exercise'] = column_types.pop('prop')

data_feature_trans['nitr'] = (
    data_feature_trans['nitr']
    .replace(mappings['nitr'])
    .astype('category'))
data_feature_trans = data_feature_trans.rename(columns={'nitr': 'nitrates_used_during_exercise_ECG'})
column_types['nitrates_used_during_exercise_ECG'] = column_types.pop('nitr')

data_feature_trans['pro'] = (
    data_feature_trans['pro']
    .replace(mappings['pro'])
    .astype('category'))
data_feature_trans = data_feature_trans.rename(columns={'pro': 'calcium_channel_blocker_used_during_exercise_ECG'})
column_types['calcium_channel_blocker_used_during_exercise_ECG'] = column_types.pop('pro')

data_feature_trans['diuretic'] = (
    data_feature_trans['diuretic']
    .replace(mappings['diuretic'])
    .astype('category'))
data_feature_trans = data_feature_trans.rename(columns={'diuretic': 'diuretic_used_during_exercise_ECG'})
column_types['diuretic_used_during_exercise_ECG'] = column_types.pop('diuretic')

data_feature_trans['proto'] = (
    data_feature_trans['proto']
    .replace(mappings['proto'])
    .astype('category'))

data_feature_trans['exang'] = (
    data_feature_trans['exang']
    .replace({0:'no',1:'yes'})
    .astype('category'))
data_feature_trans = data_feature_trans.rename(columns={'exang': 'exerise_induced_angina'})
column_types['exerise_induced_angina'] = column_types.pop('exang')

data_feature_trans['xhypo'] = (
    data_feature_trans['xhypo']
    .replace({0:'no',1:'yes'})
    .astype('category'))

data_feature_trans['slope'] = (
    data_feature_trans['slope']
    .replace({1:'upsloping',2:'flat',3:'downsloping'})
    .astype('category'))
data_feature_trans = data_feature_trans.rename(columns={'slope': 'slope_peak_ex_ST_segment'})
column_types['slope_peak_ex_ST_segment'] = column_types.pop('slope')

data_feature_trans['restwm'] = (
    data_feature_trans['restwm']
    .replace({0:'none',1:'mild or moderate',2:'moderate or severe',3:'akinesis or dyskmem'})
    .astype('category'))

data_feature_trans['exerwm'] = (
    data_feature_trans['exerwm']
    .replace({0:'none',1:'mild or moderate',2:'moderate or severe',3:'akinesis or dyskmem'})
    .astype('category'))

data_feature_trans['thal'] = (
    data_feature_trans['thal']
    .replace({3:'normal',6:'fixed defect',7:'reversable defect'})
    .astype('category'))


data_feature_trans['cmo'] = (
    data_feature_trans['cmo']
    .replace({1: 'January', 2: 'February', 3: 'March', 4: 'April', 5: 'May', 6: 'June',
              7: 'July', 8: 'August', 9: 'September', 10: 'October', 11: 'November', 12: 'December'})
    .astype('category'))

data_feature_trans['target_label'] = (
    data_feature_trans['target']
    .replace({0:'< 50% diameter narrowing',1:'> 50% diameter narrowing'})
    .astype('category'))

data_feature_trans
# Out:
#       age     sex     painloc              painexer              relrest  \
# 0    63.0    male         NaN                   NaN                  NaN
# 1    67.0    male         NaN                   NaN                  NaN
# 2    67.0    male         NaN                   NaN                  NaN
# 3    37.0    male         NaN                   NaN                  NaN
# 4    41.0  female         NaN                   NaN                  NaN
# ..    ...     ...         ...                   ...                  ...
# 894  54.0    male  substernal  provoked by exertion  relieved after rest
# 895  56.0    male  substernal  provoked by exertion  relieved after rest
# 896  56.0    male   otherwise  provoked by exertion  relieved after rest
# 897  54.0    male  substernal  provoked by exertion  relieved after rest
# 898  66.0  female  substernal  provoked by exertion  relieved after rest
#
#                    cp  trestbps  htn   chol smoke  ...               thal  \
# 0      typical angina     145.0  1.0  233.0   NaN  ...       fixed defect
# 1        asymptomatic     160.0  1.0  286.0   NaN  ...             normal
# 2        asymptomatic     120.0  1.0  229.0   NaN  ...  reversable defect
# 3    non-anginal pain     130.0  0.0  250.0   NaN  ...             normal
# 4     atypical angina     130.0  1.0  204.0   NaN  ...             normal
# ..                ...       ...  ...    ...   ...  ...                ...
# 894      asymptomatic     180.0  0.0    0.0   NaN  ...  reversable defect
# 895      asymptomatic     125.0  0.0    0.0   yes  ...  reversable defect
# 896  non-anginal pain     125.0  0.0    0.0   NaN  ...  reversable defect
# 897      asymptomatic     130.0  0.0    0.0   NaN  ...  reversable defect
# 898      asymptomatic     155.0  0.0    0.0   NaN  ...  reversable defect
#
#      thalsev thalpul earlobe       cmo  cday   cyr  target  pncaden  \
# 0        NaN     NaN     NaN  February  16.0  81.0     0.0      0.0
# 1        NaN     NaN     NaN  February   5.0  81.0     1.0      0.0
# 2        NaN     NaN     NaN  February  20.0  81.0     1.0      0.0
# 3        NaN     NaN     NaN  February   4.0  81.0     0.0      0.0
# 4        NaN     NaN     NaN  February  18.0  81.0     0.0      0.0
# ..       ...     ...     ...       ...   ...   ...     ...      ...
# 894      1.0     0.0     NaN       May   7.0  85.0     1.0      3.0
# 895      2.0     0.0     NaN      June  20.0  85.0     1.0      3.0
# 896      1.0     0.0     NaN      June  25.0  85.0     1.0      2.0
# 897      2.0     0.0     NaN      July   4.0  85.0     1.0      3.0
# 898      1.0     0.0     NaN      July   4.0  85.0     1.0      3.0
#
#                  target_label
# 0    < 50% diameter narrowing
# 1    > 50% diameter narrowing
# 2    > 50% diameter narrowing
# 3    < 50% diameter narrowing
# 4    < 50% diameter narrowing
# ..                        ...
# 894  > 50% diameter narrowing
# 895  > 50% diameter narrowing
# 896  > 50% diameter narrowing
# 897  > 50% diameter narrowing
# 898  > 50% diameter narrowing
#
# [899 rows x 55 columns]

# %% [markdown]
# I put the transformed categorical values in a new table called data_feature_trans so as not to get confused with the original data.

# %% [markdown]
# ## Final plots

# %%
len(num_cols)
# Out:
# 24

# %%
fig,axs = plt.subplots(6,4,figsize=(20,40))

for i, ind in enumerate(num_cols):

    if data[ind].count() > 1:
        sns.boxplot(data=data_feature_trans, x='target', y=ind, hue='target', ax=axs[i//4, i%4], legend=False)
        axs[i//4, i%4].set_title(ind)
        axs[i//4, i%4].set_xticks([0, 1])
        axs[i//4, i%4].set_xticklabels(['< 50%', '> 50%'])
        axs[i//4, i%4].set_xlabel('Chance of diameter narrowing')
    else:
        # with only one value, just a bar plot
        grouped_data = data_feature_trans.groupby([ind, 'target_label'], observed=False).size().reset_index(name='count')
        sns.barplot(data=grouped_data, x=ind, y='count', hue='target_label', ax=axs[i//4, i%4])


fig.tight_layout()

# %% [markdown]
# For all the numerical columns:
# 1. age : Older people seem to be at higher risk for heart disease. Those who are younger and have a high risk for heart disease seem to be outliers based on the boxplot outliers.
# 2. pncaden : does seem to be much of an idicator
# 3. trestbps (resting blood pressure) : slightly higher values for higher risk of heart disease, but not too much
# 4. chol : extreme highs and lows for risk of heart disease. Healthy values fall into a tigher range.
# 5. cigs : daily cigarette use seems similar
# 6. years (years smoking) : slightly higher for heart diseases, but not too much
# 7. thaldur (duration of exercise test in minutes) : higher for people with lower risk of heart disease
# 8. thaltime (time when ST measure depression was noted) : seems to have little indication
# 9. met (mets achieved) : seems to have little indication
# 10. thalach (maximum heart rate achieved) : higher for lower risk individuals
# 11. thalrest (resting heart rate) : higher for lower risk individuals
# 12. tpeakbps (peak exercise blood pressure (first of 2 parts)) : higher for lower risk individals, but barely
# 13. tpeakbpd (peak exercise blood pressure (second of 2 parts)) : little indication
# 14. trestbpd (resting blood pressure) : no difference
# 15. oldpeak (ST depression induced by exercise relative to rest) : higher for people with higher risk of heart disease, also negative values (might be an error, unclear the range of this metric)
# 16. rldv5 (height at rest) : slightly higher for high risk
# 17. rldv5e (height at peak exercise): no indication
# 18. ca (number of major vessels (0-3) colored by flourosopy) : values higher than 0 is a major indication of heart problems
# 19. exerckm : only one value and it is for someone at risk
# 20. restef (rest raidonuclid (sp?) ejection fraction) : seems to be higher on average for higher risk
# 21. exeref : only values recorded are higher risk
# 22. thalsev (not used)
# 23. thalpul (not used)
# 24. earlobe (not used)

# %%
cat_cols = [key for key, value in column_types.items() if value == 'categorical']
len(cat_cols)
# Out:
# 30

# %%
fig,axs = plt.subplots(15,2,figsize=(14,80))

for i,ind in enumerate(cat_cols):
    row = i // 2 
    col = i % 2
    grouped_data = data_feature_trans.groupby([ind, 'target_label'], observed=False).size().reset_index(name='count')
    sns.barplot(data=grouped_data, x=ind, y='count', hue='target_label', ax=axs[row, col])
    axs[row, col].set_xticklabels(axs[row, col].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis tick labels
    axs[row, col].set_title(ind)
    axs[row, col].set_title(ind)
fig.tight_layout()
# Out:
# /tmp/ipykernel_661/4040048709.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[row, col].set_xticklabels(axs[row, col].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis tick labels
# /tmp/ipykernel_661/4040048709.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[row, col].set_xticklabels(axs[row, col].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis tick labels
# /tmp/ipykernel_661/4040048709.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[row, col].set_xticklabels(axs[row, col].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis tick labels
# /tmp/ipykernel_661/4040048709.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[row, col].set_xticklabels(axs[row, col].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis tick labels
# /tmp/ipykernel_661/4040048709.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[row, col].set_xticklabels(axs[row, col].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis tick labels
# /tmp/ipykernel_661/4040048709.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[row, col].set_xticklabels(axs[row, col].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis tick labels
# /tmp/ipykernel_661/4040048709.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[row, col].set_xticklabels(axs[row, col].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis tick labels
# /tmp/ipykernel_661/4040048709.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[row, col].set_xticklabels(axs[row, col].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis tick labels
# /tmp/ipykernel_661/4040048709.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[row, col].set_xticklabels(axs[row, col].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis tick labels
# /tmp/ipykernel_661/4040048709.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[row, col].set_xticklabels(axs[row, col].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis tick labels
# /tmp/ipykernel_661/4040048709.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[row, col].set_xticklabels(axs[row, col].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis tick labels
# /tmp/ipykernel_661/4040048709.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[row, col].set_xticklabels(axs[row, col].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis tick labels
# /tmp/ipykernel_661/4040048709.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[row, col].set_xticklabels(axs[row, col].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis tick labels
# /tmp/ipykernel_661/4040048709.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[row, col].set_xticklabels(axs[row, col].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis tick labels
# /tmp/ipykernel_661/4040048709.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[row, col].set_xticklabels(axs[row, col].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis tick labels
# /tmp/ipykernel_661/4040048709.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[row, col].set_xticklabels(axs[row, col].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis tick labels
# /tmp/ipykernel_661/4040048709.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[row, col].set_xticklabels(axs[row, col].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis tick labels
# /tmp/ipykernel_661/4040048709.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[row, col].set_xticklabels(axs[row, col].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis tick labels
# /tmp/ipykernel_661/4040048709.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[row, col].set_xticklabels(axs[row, col].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis tick labels
# /tmp/ipykernel_661/4040048709.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[row, col].set_xticklabels(axs[row, col].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis tick labels
# /tmp/ipykernel_661/4040048709.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[row, col].set_xticklabels(axs[row, col].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis tick labels
# /tmp/ipykernel_661/4040048709.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[row, col].set_xticklabels(axs[row, col].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis tick labels
# /tmp/ipykernel_661/4040048709.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[row, col].set_xticklabels(axs[row, col].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis tick labels
# /tmp/ipykernel_661/4040048709.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[row, col].set_xticklabels(axs[row, col].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis tick labels
# /tmp/ipykernel_661/4040048709.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[row, col].set_xticklabels(axs[row, col].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis tick labels
# /tmp/ipykernel_661/4040048709.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[row, col].set_xticklabels(axs[row, col].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis tick labels
# /tmp/ipykernel_661/4040048709.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[row, col].set_xticklabels(axs[row, col].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis tick labels
# /tmp/ipykernel_661/4040048709.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[row, col].set_xticklabels(axs[row, col].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis tick labels
# /tmp/ipykernel_661/4040048709.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[row, col].set_xticklabels(axs[row, col].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis tick labels
# /tmp/ipykernel_661/4040048709.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[row, col].set_xticklabels(axs[row, col].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis tick labels

# %% [markdown]
# For all categorical columns:
# 1. sex : fewer women are at risk of heart disease, more men are at risk of heart disease
# 2. painloc : substernal pain has higher risk of heart condition, otherwise has little indication
# 3. painexer : pain provoked by exertion has high indication of heart condition, otherwise has high indication of no heart condition
# 4. relrest : pain relieved after rest has high indication of heart condition, otherwise has high indication of no heart condition
# 5. cp : asymptomatic has very high indication of heart condition compared to other types
# 6. htn : if the value is 1, the patient is more likely to have a heart condition
# 7. smoke: both smokers and nonsmokers are at risk, but smokers are at a higher risk
# 8. fbs : fbs greater than 120 indicates higher risk of heart condition, less than 120 is relatively not indicative
# 9. dm : history of diabetes increases risk of heart disease
# 10. restecg : abnormalities seem to be more indicative of heart conditions
# 11. ekgmo : no indication
# 12. ekgday : no indication
# 13. ekgyr : no indication
# 14. proto : Balke seems to show the most indication of heart disease
# 15. xhypo : most people answered no to this, no indication
# 16. restwm : mild is the only category that shows low risk
# 17. exerwm : mild or moderate indicates high risk
# 18. thal : normal shows low risk
# 19. cmo : no indication
# 20. cday : no indication
# 21. cyr : no indication
# 22. family history of coronary artery disease : shows little indication
# 23. digitalis used during exercise : shows little indication
# 24. beta blocker used during exercise : yes indicates high risk
# 25. nitrates used during exercise ECG : yes shows indication of high risk
# 26. calcium channel blocker used during exercise ECG : yes indicates high risk, no has no difference
# 27. diuretic used during exercise ECG : yes indicates higher risk than no
# 28. exercise induced angina : yes indicates high risk, no indicates low risk
# 29. slope peak ex ST segment : flat indicates very high risk, downsloping indicates high risk, upsloping indicates low risk

# %%
insert_to_table(data = data, table_name = 'final_hd_data')

table_name_data = 'final_hd_data'
staging_file = 'final_hd_data.parquet'
transform(table_name_data)
# Out:
# Shape of data (899, 54)
# Shape of data (899, 54)

# %%
data_loaded = load_one(staging_file, staging_data_dir)
print(data_loaded.shape)
# Out:
# (899, 54)

# %%
data_loaded
# Out:
#       age     sex     painloc              painexer              relrest  \
# 0    63.0    male        None                  None                 None
# 1    67.0    male        None                  None                 None
# 2    67.0    male        None                  None                 None
# 3    37.0    male        None                  None                 None
# 4    41.0  female        None                  None                 None
# ..    ...     ...         ...                   ...                  ...
# 894  54.0    male  substernal  provoked by exertion  relieved after rest
# 895  56.0    male  substernal  provoked by exertion  relieved after rest
# 896  56.0    male   otherwise  provoked by exertion  relieved after rest
# 897  54.0    male  substernal  provoked by exertion  relieved after rest
# 898  66.0  female  substernal  provoked by exertion  relieved after rest
#
#                    cp  trestbps  htn   chol smoke  ...  exerwm  thal thalsev  \
# 0      typical angina     145.0  1.0  233.0  None  ...     NaN   6.0     NaN
# 1        asymptomatic     160.0  1.0  286.0  None  ...     NaN   3.0     NaN
# 2        asymptomatic     120.0  1.0  229.0  None  ...     NaN   7.0     NaN
# 3    non-anginal pain     130.0  0.0  250.0  None  ...     NaN   3.0     NaN
# 4     atypical angina     130.0  1.0  204.0  None  ...     NaN   3.0     NaN
# ..                ...       ...  ...    ...   ...  ...     ...   ...     ...
# 894      asymptomatic     180.0  0.0    0.0  None  ...     NaN   7.0     1.0
# 895      asymptomatic     125.0  0.0    0.0   yes  ...     NaN   7.0     2.0
# 896  non-anginal pain     125.0  0.0    0.0  None  ...     NaN   7.0     1.0
# 897      asymptomatic     130.0  0.0    0.0  None  ...     NaN   7.0     2.0
# 898      asymptomatic     155.0  0.0    0.0  None  ...     NaN   7.0     1.0
#
#     thalpul earlobe  cmo  cday   cyr  target  pncaden
# 0       NaN     NaN  2.0  16.0  81.0     0.0      0.0
# 1       NaN     NaN  2.0   5.0  81.0     1.0      0.0
# 2       NaN     NaN  2.0  20.0  81.0     1.0      0.0
# 3       NaN     NaN  2.0   4.0  81.0     0.0      0.0
# 4       NaN     NaN  2.0  18.0  81.0     0.0      0.0
# ..      ...     ...  ...   ...   ...     ...      ...
# 894     0.0     NaN  5.0   7.0  85.0     1.0      3.0
# 895     0.0     NaN  6.0  20.0  85.0     1.0      3.0
# 896     0.0     NaN  6.0  25.0  85.0     1.0      2.0
# 897     0.0     NaN  7.0   4.0  85.0     1.0      3.0
# 898     0.0     NaN  7.0   4.0  85.0     1.0      3.0
#
# [899 rows x 54 columns]

# %%
insert_to_table(data = data_feature_trans, table_name = 'final_hd_data_feature_trans')

table_name_feature = 'final_hd_data_feature_trans'
staging_file = 'final_hd_data_feature_trans.parquet'
transform(table_name_feature)
# Out:
# Shape of data (899, 55)
# Shape of data (899, 55)

# %%
data_loaded_feature = load_one(staging_file_feature, staging_data_dir)
print(data_loaded_feature.shape)
# Out:
# (899, 55)

# %%
data_loaded_feature
# Out:
#       age     sex     painloc              painexer              relrest  \
# 0    63.0    male        None                  None                 None
# 1    67.0    male        None                  None                 None
# 2    67.0    male        None                  None                 None
# 3    37.0    male        None                  None                 None
# 4    41.0  female        None                  None                 None
# ..    ...     ...         ...                   ...                  ...
# 894  54.0    male  substernal  provoked by exertion  relieved after rest
# 895  56.0    male  substernal  provoked by exertion  relieved after rest
# 896  56.0    male   otherwise  provoked by exertion  relieved after rest
# 897  54.0    male  substernal  provoked by exertion  relieved after rest
# 898  66.0  female  substernal  provoked by exertion  relieved after rest
#
#                    cp  trestbps  htn   chol smoke  ...               thal  \
# 0      typical angina     145.0  1.0  233.0  None  ...       fixed defect
# 1        asymptomatic     160.0  1.0  286.0  None  ...             normal
# 2        asymptomatic     120.0  1.0  229.0  None  ...  reversable defect
# 3    non-anginal pain     130.0  0.0  250.0  None  ...             normal
# 4     atypical angina     130.0  1.0  204.0  None  ...             normal
# ..                ...       ...  ...    ...   ...  ...                ...
# 894      asymptomatic     180.0  0.0    0.0  None  ...  reversable defect
# 895      asymptomatic     125.0  0.0    0.0   yes  ...  reversable defect
# 896  non-anginal pain     125.0  0.0    0.0  None  ...  reversable defect
# 897      asymptomatic     130.0  0.0    0.0  None  ...  reversable defect
# 898      asymptomatic     155.0  0.0    0.0  None  ...  reversable defect
#
#      thalsev thalpul earlobe       cmo  cday   cyr  target  pncaden  \
# 0        NaN     NaN     NaN  February  16.0  81.0     0.0      0.0
# 1        NaN     NaN     NaN  February   5.0  81.0     1.0      0.0
# 2        NaN     NaN     NaN  February  20.0  81.0     1.0      0.0
# 3        NaN     NaN     NaN  February   4.0  81.0     0.0      0.0
# 4        NaN     NaN     NaN  February  18.0  81.0     0.0      0.0
# ..       ...     ...     ...       ...   ...   ...     ...      ...
# 894      1.0     0.0     NaN       May   7.0  85.0     1.0      3.0
# 895      2.0     0.0     NaN      June  20.0  85.0     1.0      3.0
# 896      1.0     0.0     NaN      June  25.0  85.0     1.0      2.0
# 897      2.0     0.0     NaN      July   4.0  85.0     1.0      3.0
# 898      1.0     0.0     NaN      July   4.0  85.0     1.0      3.0
#
#                  target_label
# 0    < 50% diameter narrowing
# 1    > 50% diameter narrowing
# 2    > 50% diameter narrowing
# 3    < 50% diameter narrowing
# 4    < 50% diameter narrowing
# ..                        ...
# 894  > 50% diameter narrowing
# 895  > 50% diameter narrowing
# 896  > 50% diameter narrowing
# 897  > 50% diameter narrowing
# 898  > 50% diameter narrowing
#
# [899 rows x 55 columns]
